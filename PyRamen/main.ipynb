# %%
# Import pertinent python libraries
import csv
from pathlib import Path



# Establish current directory
current_dir = Path.cwd()
print(current_dir)



# Set file paths for menu data and sales data
menu_csv = current_dir/'02-Homework_02-Python_Instructions_PyRamen_Resources_menu_data.csv'
sales_csv = current_dir/'02-Homework_02-Python_Instructions_PyRamen_Resources_sales_data.csv'


# Establish variables
menu = []
sales = []
report = {}
quantity = []
menu_item = []



# Read menu data
with open(menu_csv) as menu_data:
    
    csv_reader_menu = csv.reader(menu_data, delimiter = ',')
    
    menu_header = next(csv_reader_menu)
        
    # loop through data and create menu list
    for row in csv_reader_menu:
        
        menu.append(row)
    


# Read sales data
with open(sales_csv) as sales_data:
    
    csv_reader_sales = csv.reader(sales_data, delimiter = ',')
    
    sales_header = next(csv_reader_sales)
    
    # loop through data and create sales list
    for row in csv_reader_sales:
        
        sales.append(row)
    
    
# create Quantity and Menu-Item lists
for sale in sales:
    quantity.append(sale[3])
    menu_item.append(sale[4])
    
    
    
    
    
# Checkpoints    
print(menu_header)    
print(sales_header)
#print(menu[0:5])
print(sales[0:5])
# Out:
# /Users/AndrewSM/Education/George Washington University FinTech Bootcamp/Homework/python-homework/PyRamen
# ['item', 'category', 'description', 'price', 'cost']
# ['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item']
# [['1', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen'], ['2', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen'], ['3', '01-01-2017', '8421920068932819', '3', 'tori paitan ramen'], ['4', '01-01-2017', '8421920068932819', '3', 'tori paitan ramen'], ['5', '01-01-2017', '4787310681569648', '1', 'truffle butter ramen']]
# ['spicy miso ramen', 'spicy miso ramen', 'tori paitan ramen', 'tori paitan ramen', 'truffle butter ramen', 'truffle butter ramen', 'tonkotsu ramen', 'tonkotsu ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'shio ramen', 'shio ramen', 'tori paitan ramen', 'tori paitan ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'spicy miso ramen', 'spicy miso ramen', 'truffle butter ramen', 'truffle butter ramen', 'tonkotsu ramen', 'tonkotsu ramen', 'truffle butter ramen', 'truffle butter ramen', 'tori paitan ramen', 'tori paitan ramen', 'spicy miso ramen', 'spicy miso ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'vegetarian spicy miso', 'vegetarian spicy miso', 'tonkotsu ramen', 'tonkotsu ramen', 'miso crab ramen', 'miso crab ramen', 'miso crab ramen', 'miso crab ramen', 'nagomi shoyu', 'nagomi shoyu', 'truffle butter ramen', 'truffle butter ramen', 'tori paitan ramen', 'tori paitan ramen', 'truffle butter ramen', 'truffle butter ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'soft-shell miso crab ramen', 'soft-shell miso crab ramen', 'nagomi shoyu', 'nagomi shoyu', 'tori paitan ramen', 'tori paitan ramen', 'shio ramen', 'shio ramen', 'nagomi shoyu', 'nagomi shoyu', 'soft-shell miso crab ramen', 'soft-shell miso crab ramen', 'tonkotsu ramen', 'tonkotsu ramen', 'truffle butter ramen', 'truffle butter ramen', 'spicy miso ramen', 'spicy miso ramen', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'soft-shell miso crab ramen', 'soft-shell miso crab ramen', 'spicy miso ramen', 'spicy miso ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'miso crab ramen', 'miso crab ramen', 'truffle butter ramen', 'truffle butter ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'tori paitan ramen', 'tori paitan ramen', 'tonkotsu ramen', 'tonkotsu ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'tonkotsu ramen', 'tonkotsu ramen', 'truffle butter ramen', 'truffle butter ramen', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'truffle butter ramen', 'truffle butter ramen', 'nagomi shoyu', 'nagomi shoyu', 'truffle butter ramen', 'truffle butter ramen', 'tori paitan ramen', 'tori paitan ramen', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian curry + king trumpet mushroom ramen', 'spicy miso ramen', 'spicy miso ramen', 'tori paitan ramen', 'tori paitan ramen', 'tori paitan ramen', 'tori paitan ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian curry + king trumpet mushroom ramen', 'nagomi shoyu', 'nagomi shoyu', 'nagomi shoyu', 'nagomi shoyu', 'burnt garlic tonkotsu ramen', 'burnt garlic tonkotsu ramen', 'nagomi shoyu', 'nagomi shoyu', 'vegetarian spicy miso', 'vegetarian spicy miso', 'truffle butter ramen', 'truffle butter ramen', 'truffle butter ramen', 'truffle butter ramen', 'shio ramen', 'shio ramen', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian curry + king trumpet mushroom ramen', 'nagomi shoyu', 'nagomi shoyu', 'vegetarian spicy miso', 'vegetarian spicy miso', 'vegetarian curry + king trumpet mushroom ramen', 'vegetarian curry + king trumpet mushroom ramen', 'shio ramen', 'shio ramen', 'shio ramen', 'shio ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'soft-shell miso crab ramen', 'soft-shell miso crab ramen', 'shio ramen', 'shio ramen', 'vegetarian spicy miso', 'vegetarian spicy miso', 'nagomi shoyu', 'nagomi shoyu', 'vegetarian spicy miso', 'vegetarian spicy miso', 'tori paitan ramen', 'tori paitan ramen', 'miso crab ramen', 'miso crab ramen', 'vegetarian curry + king tr ...
